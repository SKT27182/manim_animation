# %% [markdown]
# # imports

# %%
from manim import *
# Out:
# Manim Community v0.17.2

# %%
param = "-v WARNING  --progress_bar None -ql -s -r 600,300 --disable_caching Shapes"
paramVideo = "-v WARNING  --progress_bar None -ql -r 600,300 --disable_caching MyVideo"

# %% [markdown]
# [Refrence-1](https://docs.manim.community/en/stable/tutorials/building_blocks.html)
#
# [Refrence-2](https://flyingframes.readthedocs.io/en/latest/ch3.html)
#
# [Mobject's gallery](https://flyingframes.readthedocs.io/en/latest/ch2.html)

# %% [markdown]
# # The Bulding Blocks

# %% [markdown]
# Manim has three bulding blocks:
#
# 1. Mathmatical Object, mobjects Mobject Class
# 2. Animation, Animation Class
# 3. Scenes, Scene Class
#
# - In this notebook, we'll work with just Mobjects.

# %% [markdown]
# # Mobjects

# %% [markdown]
# Mobjects are the basic building blocks for all manim animations. Each class that derives from Mobject represents an object that can be displayed on the screen. For example, simple shapes such as Circle, Arrow, and Rectangle are all mobjects. More complicated constructs such as Axes, FunctionGraph, or BarChart are mobjects as well.
#
# If you try to display an instance of Mobject on the screen, you will only see an empty frame. The reason is that the Mobject class is an abstract base class of all other mobjects. Usually, you will create instances of its derived classes. One of these derived classes is VMobject. The V stands for `Vectorized Mobject`. In essence, a vmobject is a mobject that uses vector graphics to be displayed.
#
# - Any object that can be displayed on the screen is a mobject, even if it is not necessarily mathematical in nature.

# %% [markdown]
# ## Creating and displaying mobjects

# %% [markdown]
# Usually all of the code in a manim script is put inside the construct() method of a Scene class. To display a mobject on the screen, call the add() method of the containing Scene. This is the principal way of displaying a mobject on the screen when it is not being animated. To remove a mobject from the screen, simply call the remove() method from the containing Scene.

# %%
# %%manim $paramVideo
#
# class MyVideo(Scene):
#     def construct(self):
#         circle = Circle()
#         self.add(circle)
#         self.wait(1)
#         self.remove(circle)
#         self.wait(1)
# Out:
# <video src="media/jupyter/MyVideo@2023-02-01@02-15-28.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Placing mobjects

# %% [markdown]
# - Let’s define a new Scene called Shapes and add() some mobjects to it. This script generates a static picture that displays a circle, a square, and a triangle:

# %%
# %%manim $param
#
# class Shapes(Scene):
#     def construct(self):
#         circle = Circle()
#         square = Square()
#         triangle = Triangle()
#
#         circle.shift(LEFT)
#         square.shift(UP)
#         triangle.shift(RIGHT)
#
#         self.add(circle, square, triangle)
#         self.wait(1)

# %% [markdown]
# By default, mobjects are placed at the center of coordinates, or origin, when they are first created. They are also given some default colors. Further, the Shapes scene places the mobjects by using the shift() method.
#
# - Unlike other graphics software, manim places the center of coordinates at the center of the screen. The positive vertical direction is up, and the positive horizontal direction is right. See also the constants ORIGIN, UP, DOWN, LEFT, RIGHT, and others, defined in the constants module.

# %%
# %%manim $param
#
# class Shapes(Scene):
#     def construct(self):
#         circle = Circle()
#         square = Square()
#         triangle = Triangle()
#
#         # place the circle two units left from the origin
#         circle.move_to(LEFT * 2)
#         # place the square to the left of the circle
#         square.next_to(circle, 5*LEFT)
#         # align the left border of the triangle to the left border of the circle
#         triangle.align_to(circle, LEFT)
#
#         self.add(circle, square, triangle)
#         self.wait(1)

# %%
ORIGIN, UP, DOWN, LEFT, RIGHT, IN, OUT, UL, UR, DL, DR
# Out:
# (array([0., 0., 0.]),
#  array([0., 1., 0.]),
#  array([ 0., -1.,  0.]),
#  array([-1.,  0.,  0.]),
#  array([1., 0., 0.]),
#  array([ 0.,  0., -1.]),
#  array([0., 0., 1.]),
#  array([-1.,  1.,  0.]),
#  array([1., 1., 0.]),
#  array([-1., -1.,  0.]),
#  array([ 1., -1.,  0.]))

# %% [markdown]
# - UL : Upper Left
# - UR : Upper Right
# - DL : Down Left
# - DR : Down Right

# %% [markdown]
# The move_to() method uses absolute units (measured relative to the ORIGIN), while next_to() uses relative units (measured from the mobject passed as the first argument). align_to() uses LEFT not as measuring units but as a way to determine the border to use for alignment. The coordinates of the borders of a mobject are determined using an imaginary bounding box around it.

# %% [markdown]
# ### set positions

# %% [markdown]
# Some important mobject methods for setting positions are:
#
# - move_to()
# - shift()
# - next_to()
# - align_to()
# - to_corner()
# - to_edge()
# - arrange()
# - arrange_in_grid()

# %%
dORIGIN= Dot(color= BLUE,radius=0.5)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         d= Dot(color= YELLOW, radius=0.5)
#         d.shift(2*RIGHT)
#         self.add(dORIGIN, d)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         d= Dot(color= YELLOW, radius=0.5)
#         d.shift(3*RIGHT+0.8*UP)
#         self.add(dORIGIN, d)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         d= Dot(color= ORANGE, radius=0.5)
#         d.next_to(dORIGIN, LEFT)
#         self.add(dORIGIN, d)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         d= Dot(color= ORANGE, radius=0.5)
#         d.next_to(dORIGIN, LEFT, buff=0)
#         self.add(dORIGIN, d)

# %% [markdown]
# - buff=0 means that the mobjects will be touching each other. buff=0.5 means that there will be a gap of 0.5 units between the mobjects. You can use negative values for buff to make the mobjects overlap.

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         d= Dot(color= ORANGE, radius=0.5)
#         d.next_to(dORIGIN, UL,buff=-0.5) # UL is UPLEFT
#         self.add(dORIGIN, d)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         d= Dot(color= ORANGE, radius=0.5)
#         d.to_edge(LEFT)
#         self.add(dORIGIN, d)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         s= Star(stroke_width=10)
#         d=Dot(color= ORANGE, radius=0.5)
#         d.align_to(s,DOWN)
#         self.add(s,d)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         s= Star(stroke_width=10)
#         d=Dot(color= ORANGE, radius=0.5)
#         d.next_to(s,RIGHT, aligned_edge=UP) #next to and align combined
#         self.add(s,d)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         for i in range(0,10):
#             self.add(Dot(color= ORANGE, radius=0.5))
#         VGroup(*self.mobjects).arrange()

# %% [markdown]
# `arrange` arranges the mobjects in a row or column. The default is a row, which is done by using `arrange(LEFT)` or `arrange(RIGHT)`. Using `UP` or `DOWN` arranges them in a column.

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         for i in range(0,10):
#             self.add(Dot(color= ORANGE, radius=0.5))
#         VGroup(*self.mobjects).arrange(UP).scale(0.5)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         for i in range(0,24):
#             self.add(Dot(color= ORANGE, radius=0.1*i))
#         # VGroup(*self.mobjects).arrange_in_grid(cols=6)

# %% [markdown]
# In the above example all the dots are placed at the same position. To place them in a grid, use the arrange_in_grid() method. The first argument is the number of rows, and the second argument is the number of columns. The optional argument buff is the distance between the mobjects. The optional argument aligned_edge is the edge of the mobjects that will be aligned. The default is LEFT.

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         for i in range(0,24):
#             self.add(Dot(color= ORANGE, radius=0.2))
#         VGroup(*self.mobjects).arrange_in_grid(cols=6).scale(2.5)

# %% [markdown]
# ### get positions

# %% [markdown]
# The most important methods to get positions:
#
# - get_center()
# - get_top()
# - get_bottom()
# - get_left()
# - get_right()
# - get_corner()
# - get_edge()
# - get_bounding_box_point()
# - get_bounding_box()
# - get_critical_point()
# - get_critical_points()
# - get_start()
# - get_end()
# - get_midpoint()
# - get_length()
# - get_width()
# - get_height()
# - get_x()
# - get_y()
# - get_z()
# - get_center_of_mass()
# - get_center_of_mass_of_points()
# - get_center_of_mass_of_points_about_points()

# %%
s= Star(stroke_width=10)
d=Dot(color= YELLOW, radius=0.2)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pos= s.get_center()
#         self.add(s, d.shift(pos))

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pos= s.get_center_of_mass()
#         self.add(s, d.move_to(pos))

# %% [markdown]
# - There is a very subtle difference between `move_to` and `shift`. `shift` is shifting the mobject. Calling it twice will shift the mobject twice. `move_to` is moving the mobject to a specific point. Calling it twice will move the mobject to the second point.

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pos= s.get_center()
#         d2 = d.copy()
#         # change the color of the copy
#         d2.set_color(ORANGE)
#         self.add(s, d, d2.move_to(pos*10))

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pos= s.get_top()
#         self.add(s, d.move_to(pos))

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pos= s.get_right()
#         self.add(s, d.move_to(pos))

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pos= s.get_bottom()
#         self.add(s, d.move_to(pos))

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pos= s.get_left()
#         self.add(s, d.move_to(pos))

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pos= s.get_corner(UL)
#         self.add(s, d.move_to(pos))

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pos= s.get_corner(DR)
#         self.add(s, d.move_to(pos))

# %% [markdown]
# - `get_start()` and `get_end()` are only defined for Line and Curves. `get_midpoint()` is only defined for Curves.

# %%
arc= Arc(radius=1.0, start_angle=-PI/16, angle=PI, stroke_width=10)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pos1= arc.get_start()
#         pos2= arc.get_end()
#         d2 = d.copy()
#         # change the color of the copy
#         d2.set_color(ORANGE)
#         self.add(arc, d.move_to(pos1), d2.move_to(pos2))

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pos= arc.get_midpoint()
#         self.add(arc, d.move_to(pos))

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pos= arc.point_from_proportion(0.2) # 0.2 is the proportion of the arc length from the start
#         self.add(arc, d.move_to(pos))

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pos= arc.get_center()
#         self.add(arc, d.move_to(pos))

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pos= arc.get_center_of_mass()
#         self.add(arc, d.move_to(pos))

# %% [markdown]
# `get_center_of_mass()` returns the center of mass of the mobject.

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pos= arc.get_arc_center()
#         self.add(arc, d.move_to(pos))

# %% [markdown]
# - `get_arc_center()` returns the center of the circle that the mobject is a part of.

# %% [markdown]
# - #Example for `get_x` , `get_y`, `set_x` and `set_y`

# %%
# %%manim $param
# class Shapes(Scene): #Example for `get_x` , `get_y`, `set_x` and `set_y`
#     def construct(self):
#         d = Dot(point=[3,1,0],radius=0.2,color= BLUE)
#         triangle= Triangle(color=YELLOW, stroke_width=10).scale(0.5)
#         x_pos=d.get_x()
#         print(x_pos)
#         triangle.set_x(x_pos)
#         self.add(d, triangle)
# Out:
# 3.0

# %%
# %%manim $param
# class Shapes(Scene): #Example for `get_x` , `get_y`, `set_x` and `set_y`
#     def construct(self):
#         d = Dot(point=[3,1,0],radius=0.2,color= BLUE)
#         triangle= Triangle(color=YELLOW, stroke_width=10).scale(0.5)
#         y_pos=d.get_y()
#         print(y_pos)
#         triangle.set_y(y_pos)
#         self.add(d, triangle)
# Out:
# 1.0

# %% [markdown]
# The set_x and set_y methods set the x and y coordinates of the mobject. The get_x and get_y methods get the x and y coordinates of the mobject. We see, for the triangle that when we set the x-coordinate, the traingle is shifted to that x position with y coordinate still being 0. Similarly, when we set the y-coordinate, the traingle is shifted to that y position with x coordinate still being 0.

# %% [markdown]
# ## Scaling, Stretching and Rotating

# %% [markdown]
# ### Scaling and stretching

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         d= Dot(color= YELLOW)
#         d.scale(10)
#         self.add(d)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         d= Dot(color= YELLOW)
#         d.scale(10)
#         d.stretch(4, dim = 0) # dim = 0 means vertical
#         self.add(d)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         d= Dot(color= YELLOW)
#         d.scale(10)
#         d.stretch(2, dim = 1) # dim = 1 means horizontal
#         self.add(d)

# %% [markdown]
# We see that scaling can be done horizonatly or vertically by passing the dim argument.

# %% [markdown]
# We can also apply matrix transformations to the mobjects. For example:

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         d= Dot(color= YELLOW)
#         d.scale(10)
#         d.apply_matrix([[0.5, 0.5, 0], # shear matrix
#                         [ 0 ,  1 , 0],
#                         [ 0 ,  0 , 1]])
#         self.add(d)

# %% [markdown]
# ### Rotating

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pentagon = Polygon(np.array([0,0,0]), np.array([1,0,0]), np.array([1,1,0]), np.array([0.5,1.5,0]), np.array([0,1,0]), color= BLUE, fill_opacity=0.5, stroke_width=10)
#         self.add(pentagon.copy())
#         pentagon.rotate(PI/2).shift(2*RIGHT)
#
#         self.add(pentagon)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pentagon = Polygon(np.array([0,0,0]), np.array([1,0,0]), np.array([1,1,0]), np.array([0.5,1.5,0]), np.array([0,1,0]), color= BLUE, fill_opacity=0.5, stroke_width=10)
#         self.add(pentagon.copy())
#         pentagon.rotate(-20*DEGREES).shift(2*RIGHT)
#         self.add( pentagon)

# %% [markdown]
# The `mobject.rotate` method takes the angle by which rotation has to be performed. By default, the rotation is performed about the origin and the angle is given in radian and it is `anticlock-wise`. In second example, we saw how to pass degrees as the angle.

# %% [markdown]
# Now, we'll have a look on how to rotate about a point other than the origin.

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         pentagon = Polygon(np.array([0,0,0]), np.array([1,0,0]), np.array([1,1,0]), np.array([0.5,1.5,0]), np.array([0,1,0]), color= BLUE, fill_opacity=0.5, stroke_width=10)
#         self.add(pentagon.copy())
#         pentagon.rotate(about_point=2*LEFT , angle=-180*DEGREES)
#         self.add(pentagon, Dot(2*LEFT,radius=0.1))

# %% [markdown]
# - Let's rotate the pentagon about the point (2,2) by 90 degrees.

# %%
# %%manim $param
#
# class Shapes(Scene):
#     def construct(self):
#         pentagon = Polygon(np.array([0,0,0]), np.array([1,0,0]), np.array([1,1,0]), np.array([0.5,1.5,0]), np.array([0,1,0]), color= BLUE, fill_opacity=0.5, stroke_width=10)
#
#         pentagon.rotate(axis=UP , angle=50*DEGREES).shift(2*RIGHT)
#
#         self.add( pentagon)

# %%
# ignore this cell, only for setup
YES = Tex(r"\checkmark", color=GREEN, stroke_width=8).scale(3).to_edge(LEFT, buff=1)
BEST = YES.copy()
BEST.add(Star(color= YELLOW, fill_opacity=1).scale(0.5).move_to(BEST).shift(0.5*DOWN+0.5*RIGHT))
NO  = Cross(Square(), stroke_color = RED_D, stroke_width = 15).scale(0.5).move_to(YES)

# %% [markdown]
# ## Colors, Opacity and Stroke width

# %% [markdown]
# ### Colors

# %% [markdown]
# `Color` parameters for Mobjects are `stroke_color`, `fill_color` and `color`. The parameter color automatically sets both stroke_color and fill_color.
#
# The recommended ways to set colors are via `c = Circle(fill_color= BLUE, fill_opacity= 1 ) , c.set_fill(color=RED) or c.set_style(fill_color=GREEN)`
#
# Not possible are c.fill_color=YELLOW , c.set(fill_color=YELLOW) and c.set_fill_color(YELLOW)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         c = Square(fill_color= BLUE, fill_opacity= 1 )
#         self.add(BEST,c)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         c = Square(fill_color= BLUE, fill_opacity= 1)
#         c.set_fill(color=RED)
#         self.add(BEST,c)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         c = Square(fill_color= BLUE, fill_opacity= 1)
#         c.set_style(fill_color=GREEN)
#         self.add(BEST,c)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         self.camera.background_color = PURPLE
#         self.add(BEST)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         c = Square(fill_opacity= 1)
#         c.fill_color=YELLOW
#         self.add(NO,c)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         c = Square(fill_opacity= 1)
#         c.set(fill_color=YELLOW)
#         self.add(NO,c)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         c = Square(fill_opacity= 1)
#         c.set_fill_color(YELLOW)
#         self.add(NO,c)
# Out:
# <string>:4: DeprecationWarning: This method is not guaranteed to stay around. Please prefer setting the attribute normally or with Mobject.set().

# %% [markdown]
# ### Opacity

# %% [markdown]
# `Opacity` parameters for Mobjects are `fill_opacity` and `stroke_opacity` (there is not opacity here).
#
# The recommended ways to set opacity are via `c = Circle(fill_color= BLUE, fill_opacity= 0.5 ) , c.set_fill(color=RED) or c.set_style(fill_color=GREEN)`
#
# Analog to colors, c.fill_opacity=1, c.set(fill_opacity=1) and c.set_fill_opacity(1) are not possible. (to keep things short, these examples are not shown).

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         c = Ellipse(color= YELLOW, fill_opacity=0.3).scale(2)
#         self.add(BEST,c)

# %%
# %%manim  $param
# class Sha(Scene):
#     def construct(self):
#         c = Ellipse(color= YELLOW).scale(2)
#         c.set_fill(opacity=0.5) # be careful: here, it must be `opacity` and not `fill_opacity` !
#         self.add(BEST,c)

# %%
# %%manim  $param
# class Shapes(Scene):
#     def construct(self):
#         c = Ellipse(color= YELLOW).scale(2)
#         c.set_style(fill_opacity=0.7) # and here, it must be `fill_opacity` and not `opacity` !
#         self.add(BEST,c)

# %% [markdown]
# **Note :** For opacity, if you are applying it while creating the object or by `set_style`, the parameter is `fill_opacity`. However, if you are applying it by `set_fill`, the parameter is `opacity`. same was for color.

# %% [markdown]
# ### Stroke width

# %% [markdown]
# Strokes can be set in multiple ways:
#
# - The recommended ways are via `Circle(stroke_width=30)` , `c.set_stroke(width = 30)` or `c.set_style(stroke_width= 30)`
#
# - Also possible, but not the best solution is `c.stroke_width = 30` and `c.set(stroke_width = 30)`
#
# - Also possible, but `not recommended` because deprecated is `c.set_stroke_width(30)`

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         c = Circle(stroke_width=30)
#         self.add(BEST,c)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         c = Circle()
#         c.set_stroke(width = 30)
#         self.add(BEST,c)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         c = Circle()
#         c.set_style(stroke_width= 30)
#         self.add(BEST,c)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         c = Circle()
#         c.stroke_width = 30
#         self.add(YES,c)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         c = Circle()
#         c.set(stroke_width = 30)
#         self.add(YES,c)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         c = Circle()
#         c.set_stroke_width(30)
#         self.add(NO,c)
# Out:
# <string>:4: DeprecationWarning: This method is not guaranteed to stay around. Please prefer setting the attribute normally or with Mobject.set().

# %% [markdown]
# ## Layers

# %% [markdown]
# There are two main ways to change the layers of Mobjects:
#
# 1. Reordering the list of `submobjects` that where added
#
# 2. Using the `z_index`

# %% [markdown]
# ### submobjects

# %% [markdown]
# A scene stores displayed mobjects in a list.
#
# They are displayed in the order that they are added to the scene with the syntax self.add(circleLeft,circleRight)
#
# First, we have a look on positioning mobjects with self.add and the methods `self.bring_to_back` and `self.bring_to_front`. In most cases, this is completely enough.

# %%
circleLeft = Circle(color=BLUE, fill_opacity=1)  # left circle is blue and is at the origin
circleRight = Circle(color=ORANGE,fill_opacity=1).shift(RIGHT)  # right circle is orange and shifted to the right
line = Line(2*LEFT,3*RIGHT,color=YELLOW, stroke_width=20)

# %%
# %%manim  $param
# class Shapes(Scene):
#     def construct(self):
#         self.add(circleLeft,circleRight)
#         self.add(BEST)

# %% [markdown]
# - Here first Left Circle is added and then on top of it, Right Circle is added which is slightly shifted to the right.

# %%
# %%manim  $param
# class Shapes(Scene):
#     def construct(self):
#         self.add(circleRight,circleLeft)
#         self.add(BEST)

# %% [markdown]
# - Now, we bring the Right Circle to the back and we see that the Left Circle is now on top of the Right Circle.

# %%
# %%manim  $param
# class Shapes(Scene):
#     def construct(self):
#         self.add(circleLeft,circleRight, line)
#         self.add(BEST)

# %% [markdown]
# - Here line is added at last and hence it is on top of all the other mobjects.

# %%
# %%manim  $param
# class Shapes(Scene):
#     def construct(self):
#         self.add(circleLeft,circleRight, line)
#         print(self.mobjects)
#         self.bring_to_back(line)
#         print(self.mobjects)
#         self.add(BEST)
# Out:
# [Circle, Circle, Line]
# [Line, Circle, Circle]

# %%
# %%manim  $param
# class Shapes(Scene):
#     def construct(self):
#         self.add(circleLeft,circleRight, line)
#         print(self.mobjects)
#         self.bring_to_front(circleLeft)
#         print(self.mobjects)
#         self.add(BEST)
# Out:
# [Circle, Circle, Line]
# [Circle, Line, Circle]

# %% [markdown]
# ### z_index

# %% [markdown]
# `z_index` is seen by manim by one priority higher: Even when a mobject is added first to the mobject list, it will be displayed on top of the others, if it has a higher z_index.

# %% [markdown]
# The default z_index is 0. Now we will see what happens, when we increase the value of the z_index.
#
# The z_index can be changed by `triangle = Triangle(z_index=1),triangle.z_index=1 , triangle.set(z_index=1)` and `triangle.set_z_index(1)`
#
# It can not be changed using triangle.set_style(z_index=1)

# %%
#initilizing line,circle,square and triangle
BUFF= 0.5*DOWN
line = Line(3*LEFT,3*RIGHT,color=YELLOW, stroke_width=20)
circle = Circle(color=GREEN_D, fill_opacity=1).shift(LEFT+BUFF)
square = Square(color=BLUE_D, fill_opacity=1).shift(UP+BUFF)
triangle = Triangle(color=RED_D, fill_opacity=1).shift(RIGHT+BUFF)

# %%
# %%manim  $param
# class Shapes(Scene):
#     def construct(self):
#         self.add(line,triangle, square, circle)  # order matters
#         print(self.mobjects)
#         print(f"{triangle.z_index=} , {square.z_index=} , {circle.z_index=} , {line.z_index=}")
#         self.add(BEST)
# Out:
# [Line, Triangle, Square, Circle]
# triangle.z_index=0 , square.z_index=0 , circle.z_index=0 , line.z_index=0

# %%
# %%manim  $param
# class Shapes(Scene):
#     def construct(self):
#         triangle.z_index=1
#         self.add(triangle, square, circle,line)  # order matters
#         print(self.mobjects)
#         print(f"{triangle.z_index=} , {square.z_index=} , {circle.z_index=} , {line.z_index=}")
#         self.add(BEST)
# Out:
# [Triangle, Square, Circle, Line]
# triangle.z_index=1 , square.z_index=0 , circle.z_index=0 , line.z_index=0

# %% [markdown]
# Here z_index 0f traingle is 1 and hence it is on top of the circle.

# %%
# %%manim  $param
# class Shapes(Scene):
#     def construct(self):
#         triangle.z_index = 1
#         square.z_index   = 2
#         circle.z_index   = 3
#         self.add(triangle, square, circle,line)  # order matters
#         self.add(BEST)
#         print(f"{line.z_index=}")
# Out:
# line.z_index=0

# %% [markdown]
# Here the mobject with less z_index is added first and hence it is in the back and the mobject with higher z_index is added later and hence it is in the front.

# %%
# %%manim  $param
# class Shapes(Scene):
#     def construct(self):
#         triangle.z_index = 3
#         square.z_index   = 2
#         circle.z_index   = 1
#         self.add(triangle, square, circle,line)  # order matters
#         self.add(BEST)
#         print(f"{line.z_index=}")
# Out:
# line.z_index=0

# %%
# %%manim  $param
# triangle.z_index = 0
# square.z_index   = 0
# circle.z_index   = 0
# class Shapes(Scene):
#     def construct(self):
#         triangle.set(z_index=1)
#         self.add(triangle, square, circle,line)  # order matters
#         print(self.mobjects)
#         print(f"{triangle.z_index=} , {square.z_index=} , {circle.z_index=} , {line.z_index=}")
#         self.add(BEST)
# Out:
# [Triangle, Square, Circle, Line]
# triangle.z_index=1 , square.z_index=0 , circle.z_index=0 , line.z_index=0

# %%
# %%manim  $param
# triangle.z_index = 0
# square.z_index   = 0
# circle.z_index   = 0
# class Shapes(Scene):
#     def construct(self):
#         try:
#             triangle.set_style(z_index=1)  # here we expect an error! Only for didactic purpose, it is put into this `try` blog, so that no long error message is shown.
#         except TypeError:
#             print("TypeError, set_style() got an unexpected keyword argument 'z_index'. ")
#             self.add(NO)
#         self.add(triangle, square, circle,line)  # order matters
#         print(f"{triangle.z_index=} , {square.z_index=} , {circle.z_index=} , {line.z_index=}")
# Out:
# TypeError, set_style() got an unexpected keyword argument 'z_index'.
# triangle.z_index=0 , square.z_index=0 , circle.z_index=0 , line.z_index=0

# %% [markdown]
# `traingle.set_style(z_index=1)` is not possible.

# %% [markdown]
# ## VGroup and Group

# %% [markdown]
# ### VGroup

# %% [markdown]
# It is a Group of VMobjects (“V” stands for Vector)
#
# In manim VGroup is a group of VMobjects. It is used to group multiple mobjects together. This way, the same transformation can be applied to all the mobjects in the group.

# %%
#only for setup
def create_dots():
    blue1_ref= Dot(color= BLUE,       point=[-.3,-.5,0], radius=0.5)
    blue2_ref= Dot(color= BLUE_A,     point=[ .3,-.5,0], radius=0.5)
    yellow1_ref= Dot(color= YELLOW,   point=[-.3, .5,0], radius=0.5)
    yellow2_ref= Dot(color= YELLOW_A, point=[ .3, .5,0], radius=0.5)
    return blue1_ref, blue2_ref,yellow1_ref,yellow2_ref

# %%
# %%manim $param
# blue1,blue2, yellow1,yellow2 = create_dots()
# class Shapes(Scene):
#     def construct(self):
#         self.add(blue1,blue2, yellow1,yellow2)

# %%
# %%manim $param
# blue1,blue2, yellow1,yellow2 = create_dots()
# class Shapes(Scene):
#     def construct(self):
#         VGroup(yellow1,yellow2).shift(RIGHT)
#         self.add(blue1,blue2, yellow1,yellow2)

# %% [markdown]
# Here VGroup of yellow1 and yellow2 circle is shifted to the right together.

# %%
# %%manim $param
# blue1,blue2, yellow1,yellow2 = create_dots()
# class Shapes(Scene):
#     def construct(self):
#         g1=VGroup(yellow1,yellow2).set_color(RED)
#         self.add(blue1,blue2, g1)

# %%
# %%manim $param
# blue1,blue2, yellow1,yellow2 = create_dots()
# class Shapes(Scene):
#     def construct(self):
#         g1=VGroup(yellow1,yellow2).shift(0.5*DOWN)
#         g2=VGroup(blue1,blue2)
#         self.add(g1, g2)

# %%
# %%manim $param
# blue1,blue2, yellow1,yellow2 = create_dots()
# class Shapes(Scene):
#     def construct(self):
#         g1=VGroup(yellow1,yellow2).shift(0.5*DOWN)
#         g2=VGroup(blue1,blue2)
#         self.add(g2,g1)

# %%
# %%manim $param
# blue1,blue2, yellow1,yellow2 = create_dots()
# class Shapes(Scene):
#     def construct(self):
#         g1=VGroup(yellow1,yellow2).shift(0.5*DOWN)
#         g2=VGroup(blue1,blue2)
#         self.add(g2,g1)

# %% [markdown]
# here VGroup-2 is added top of VGroup-1 and hence it is on top of VGroup-1.

# %%
# %%manim $param
# blue1,blue2, yellow1,yellow2 = create_dots()
# class Shapes(Scene): # Groups of Groups
#     def construct(self):
#         g1=VGroup(yellow1,yellow2).shift(0.5*DOWN)
#         g2=VGroup(blue1,blue2)
#         gAll = VGroup(g1, g2)
#         self.add(gAll)
#         print(gAll.submobjects)
#         print(gAll.submobjects[0].submobjects)
#         print(gAll.submobjects[1].submobjects)
# Out:
# [VGroup(Dot, Dot), VGroup(Dot, Dot)]
# [Dot, Dot]
# [Dot, Dot]

# %% [markdown]
# Here we have created a new VGroup of VGroup-1 and VGroup-2. whose 1st element is VGroup-1 and 2nd element is VGroup-2.

# %%
# %%manim $param
# blue1,blue2, yellow1,yellow2 = create_dots()
# class Shapes(Scene): #setting VMobject attibutes
#     def construct(self):
#         g=VGroup(yellow1,yellow2,blue1,blue2)
#         g.set_stroke(color=PURPLE_D, width=20) # <--
#         self.add(g)

# %%
# %%manim $param
# blue1,blue2, yellow1,yellow2 = create_dots()
# class Shapes(Scene): # add syntax
#     def construct(self):
#         g=VGroup(yellow1,yellow2,blue1)
#         g.add(blue2) # <--
#         g.set_stroke(color=GREEN, width=20)
#         self.add(g)

# %%
# %%manim $param
# blue1,blue2, yellow1,yellow2 = create_dots()
# class Shapes(Scene): # += Syntax
#     def construct(self):
#         g=VGroup(yellow1,yellow2,blue1)
#         g += blue2 # <--
#         g.set_stroke(color=ORANGE, width=20)
#         self.add(g)

# %%
# %%manim $param
# blue1,blue2, yellow1,yellow2 = create_dots()
# class Shapes(Scene): # empty initilizing
#     def construct(self):
#         g=VGroup()
#         for _ in range(0,10):
#             g += yellow1.copy()
#         g.set_stroke(color=WHITE, width=20)
#         g.arrange_in_grid(rows=2) # <-- Groups and VGroups can be arranged in grids
#         g.move_to(ORIGIN)
#         self.add(g)

# %% [markdown]
# We can add one Mobject to another Mobject using `add` methods.

# %%
# %%manim $param
# blue1,blue2, yellow1,yellow2 = create_dots()
# class Shapes(Scene):  # other Mobjects can be added to any Mobjects
#     def construct(self):
#         d= Dot(color= YELLOW, radius=0.7)
#         d.add(Line(0.2*UP, 0.8*UP, color=RED,stroke_width=40))
#         self.add(d)

# %% [markdown]
# Note that in VGroup, you can add only VMobject objects. If you try to add a Mobject object, you will get an error. For example:

# %%
# %%manim $param
# dot= Dot(color= YELLOW, radius=0.5)
# image = ImageMobject(np.uint8([[200, 233, 111, 200],
#                                [255, 100, 190, 100]])).shift(2*RIGHT)
# image.height = 1
# class Shapes(Scene):
#     def construct(self):
#         self.add(dot, image)
#         try: # Image is not a VMobject!
#             VGroup(dot,image).shift(3*RIGHT)
#         except TypeError:
#             print("Adding an Mobject to a VGroup is not possible!")
#             self.add(NO)
# Out:
# Adding an Mobject to a VGroup is not possible!

# %% [markdown]
# ### Group

# %% [markdown]
# As we saw, Vgroup does not allow Mobject objects. However, Group does. Group is a group of Mobjects as well as VMobject. However, you can use only those methods which are supported by Mobjects, methods supported by VMobjects will not work.

# %%
# %%manim $param
# dot= Dot(color= YELLOW, radius=0.5)
# image = ImageMobject(np.uint8([[200, 233, 111, 200],
#                                [255, 100, 190, 100]])).shift(2*RIGHT)
# image.height = 1
# class Shapes(Scene):
#     def construct(self):
#         self.add(dot, image)
#         Group(dot,image).shift(3*RIGHT)

# %%
# %%manim $param
# blue1,blue2, yellow1,yellow2 = create_dots()
# class Shapes(Scene): #
#     def construct(self):
#         g=Group(yellow1,yellow2,blue1,blue2)
#         try:
#             g.set_stroke(color=PURPLE_D, width=20)
#         except TypeError:
#             print("TypeError!")
#             self.add(NO)
#         self.add(g)
# Out:
# TypeError!

# %% [markdown]
# Since set_stroke is a method of VMobject, it will not work.
#
# - Please note that z_index is not supported, neither for VGroup nor for Group.

# %%
# %%manim $param
# blue1,blue2, yellow1,yellow2 = create_dots()
# class Shapes(Scene):
#     def construct(self):
#         a=VGroup(yellow1,yellow2).shift(0.5*DOWN)
#         b=VGroup(blue1,blue2)
#         a.set_z_index(2)
#         b.set_z_index(1)
#         self.add(a,b)
#         self.add(NO)

# %% [markdown]
# Here z_index of yellow circles is 2 but still they are in the back because z_index is not supported by Group.

# %% [markdown]
# ## Making Mobject Classes

# %% [markdown]
# You often need to draw some Mobjects again and again. This is where classes come in. You can create your own Mobject classes. For example, if you want to draw a crescent moon, you can create a class for it. In fact, let's do it!

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         d1 = Dot(point= [0,0,0], radius=2)
#         d2 = Dot(point= [1,0,0], radius=2)
#         diff = Difference(d1,d2,fill_opacity=1,stroke_width=0)
#         self.add(diff)

# %% [markdown]
# Let's create a class for the Moon Mobject

# %%
# %%manim $param
# class Moon(VGroup):
#     def __init__(self):
#         super().__init__()
#         d1 = Dot(point= [0,0,0], radius=2)
#         d2 = Dot(point= [1,0,0], radius=2)
#         diff = Difference(d1,d2,fill_opacity=1,stroke_width=0, fill_color=BLUE)
#         self.add(diff)
#
# class Shapes(Scene):
#     def construct(self):
#         m = Moon()
#         self.add(m)

# %% [markdown]
# **Note**: Replacing `super().__init__()` with `VGroup().__init__(self)` would also work, but is discouraged to use.

# %% [markdown]
# **Note**: The class can be of type VGroup,Group, VMobject, and Mobject. It depends on what class features you want to use when choosing the classtype. `VGroup is recommended`.

# %%
# %%manim $param
# class Moon(VGroup): # <- Try what happens when you change it to VMobject
#     def __init__(self):
#         super().__init__()
#         d1 = Dot(point= [0,0,0], radius=2)
#         d2 = Dot(point= [1,0,0], radius=2)
#         diff = Difference(d1,d2,fill_opacity=1,stroke_width=0, fill_color=BLUE)
#         self.add(diff)
#
# class Shapes(Scene):
#     def construct(self):
#         m = Moon()
#         m += Line(stroke_width=40, color=BLUE_E)
#         self.add(m)

# %% [markdown]
# Let's try to make Moon class by inheriting from VMobject class.

# %%
# %%manim $param
# class Moon(VMobject): # <- Try what happens when you change it to VMobject
#     def __init__(self):
#         super().__init__()
#         d1 = Dot(point= [0,0,0], radius=2)
#         d2 = Dot(point= [1,0,0], radius=2)
#         diff = Difference(d1,d2,fill_opacity=1,stroke_width=0, fill_color=BLUE)
#         self.add(diff)
#
# class Shapes(Scene):
#     def construct(self):
#         m = Moon()
#         m += Line(stroke_width=40, color=BLUE_E)
#         self.add(m)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[203], line 1
# ----> 1 get_ipython().run_cell_magic('manim', '$param', 'class Moon(VMobject): # <- Try what happens when you change it to VMobject\n    def __init__(self):\n        super().__init__()\n        d1 = Dot(point= [0,0,0], radius=2)\n        d2 = Dot(point= [1,0,0], radius=2)\n        diff = Difference(d1,d2,fill_opacity=1,stroke_width=0, fill_color=BLUE)\n        self.add(diff)\n\nclass Shapes(Scene):\n    def construct(self):\n        m = Moon()\n        m += Line(stroke_width=40, color=BLUE_E)\n        self.add(m)\n')
#
# File ~/.virtualenv/manim/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2422, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2420 with self.builtin_trap:
#    2421     args = (magic_arg_s, cell)
# -> 2422     result = fn(*args, **kwargs)
#    2423 return result
#
# File ~/.virtualenv/manim/lib/python3.10/site-packages/manim/utils/ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File ~/.virtualenv/manim/lib/python3.10/site-packages/manim/scene/scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:12, in construct(self)
#
# File ~/.virtualenv/manim/lib/python3.10/site-packages/manim/mobject/mobject.py:467, in Mobject.__iadd__(self, mobject)
#     466 def __iadd__(self, mobject):
# --> 467     raise NotImplementedError
#
# NotImplementedError:

# %% [markdown]
# It gave error because VMobject does not have += operator.

# %%
# %%manim $param
# class Moon(VMobject): # <- Try what happens when you change it to VMobject
#     def __init__(self):
#         super().__init__()
#         d1 = Dot(point= [0,0,0], radius=2)
#         d2 = Dot(point= [1,0,0], radius=2)
#         diff = Difference(d1,d2,fill_opacity=1,stroke_width=0, fill_color=BLUE)
#         self.add(diff)
#
# class Shapes(Scene):
#     def construct(self):
#         m = Moon()
#         m.add(Line(stroke_width=40, color=BLUE_E))
#         self.add(m)

# %% [markdown]
# After changing += operator with `add` method, it worked.

# %%
# %%manim $param
# class Moon(VGroup):
#     def __init__(self,moon_color): # <- here one can init the classes with certain parameters.
#         super().__init__()
#         d1 = Dot(point= [0,0,0], radius=2)
#         d2 = Dot(point= [1,0,0], radius=2)
#         diff = Difference(d1,d2,fill_opacity=1, fill_color= moon_color)  # <- here the parameter is used
#         self.add(diff)
#
# class Shapes(Scene):
#     def construct(self):
#         m = Moon(moon_color=YELLOW) # <- here the parameter is used
#         self.add(m)

# %% [markdown]
# Let's create a class Heart by inheriting from `VGroup` class.

# %%
class Heart(VGroup):
    def __init__(self, heart_color ):
        super().__init__()
        x = 0
        y = 0
        heart_up = VGroup(
            Arc(start_angle=PI/2, angle=-PI, radius=1).shift([x, y-1, 0]),
            Arc(start_angle=-PI/2, angle=PI, radius=1).shift([x, y+1, 0]),
        )
        heart_up.rotate(90*DEGREES)

        heart_down = VGroup(
            Polygon([x-2, y+1, 0], [x+2, y+1, 0], [x, y-1, 0])
        )
        heart_down.shift(1.5*DOWN, 0.5*RIGHT)

        heart = VGroup(heart_up, heart_down)
        heart.move_to(ORIGIN)


        heart.set_fill(color=heart_color, opacity=1)
        heart.set_stroke(width=0)
        self.add(heart)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         h = Heart(heart_color=RED)
#         self.add(h)

# %%
# %%manim $param
# class Shapes(Scene):
#     def construct(self):
#         h = Heart(heart_color=PINK)
#         self.add(h)
